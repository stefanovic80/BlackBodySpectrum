# %%
from IPython.display import display 
from IPython.core.display import display, HTML #display multiple output on a cell 
display(HTML("<style>.container { width:100% !important; }</style>")) # improve cells horizontal size
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.prompt { display:none !important; }</style>"))
from IPython.core.interactiveshell import InteractiveShell # It saves you having to repeatedly type "Display"
InteractiveShell.ast_node_interactivity = "all"
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.output_result { max-width:100% !important; }</style>
# <style>.prompt { display:none !important; }</style>

# %%
# %matplotlib notebook

import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab

import matplotlib 
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 

plt.rcParams['lines.linewidth'] = 3
#plt.rcparam['axes.grid'] = True 

import warnings
warnings.filterwarnings('ignore')



font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 14}

matplotlib.rc('font', **font)

# %%
h = 6.2607e-34#js
c = 3e8 #m/s
K_B = 1.38e-23 #JK^-1
LambdaN = np.arange(200, 1200, 1) 
Lambda = LambdaN*1e-9

fig = plt.figure(figsize =(14, 9))
ax = fig.add_subplot(111)
ax.set_xlim(LambdaN[0], LambdaN[-1])
ax.grid(True)
degrees = 50
plt.xticks( rotation = degrees)
plt.yticks( rotation = degrees)
ax.set_title("Black Body Spectrum", fontweight="bold")
ax.set_xlabel("$\lambda$ (nm)", fontweight="bold")
ax.set_ylabel("emissivity ($Watt/m^2nm$)", fontweight="bold")
plt.axvline(x = 380, linewidth = 2, color = 'rebeccapurple')
plt.axvline(x = 435, linewidth = 1, color = 'indigo')

plt.axvline(x = 500, linewidth = 1, color = 'blue')
plt.axvline(x = 520, linewidth = 1, color = 'green')

plt.axvline(x = 565, linewidth = 1, color = 'yellow')
plt.axvline(x = 590, linewidth = 1, color = 'orange')

plt.axvline(x = 625, linewidth = 1, color = 'red')
plt.axvline(x = 740, linewidth = 2, color = 'r')

def plotFunction():
    line, = ax.plot(LambdaN, emissivita, label='%.0f Kelvin' %T )
    point, = ax.plot(xM, M, 'xr', ms=10, mew = 2)
    plt.legend()

for T in range(6500, 2000, -250): #Kelvin
    A = 2*np.pi*h*c**2
    alpha = h*c/(K_B*T)
    emissivita = 1e-9*A*( np.exp( alpha/Lambda ) - 1 )**-1/Lambda**5

    M = max(emissivita)
    xM = np.where(emissivita == M)[0][0]
    xM = LambdaN[xM]
    plotFunction()

plt.savefig("/home/stefano/Desktop/SpettroCorpoNero")
# Out:
# <img src="data:image/png;base64,..." width="1400">
# (200, 1199)
# (array([ 200.,  400.,  600.,  800., 1000., 1200.]),
#  <a list of 6 Text xticklabel objects>)
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text yticklabel objects>)
# Text(0.5, 1.0, 'Black Body Spectrum')
# Text(0.5, 0, '$\\lambda$ (nm)')
# Text(0, 0.5, 'emissivity ($Watt/m^2nm$)')
